# %%
import requests
import re
from bs4 import BeautifulSoup

UA={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36"}

url="http://shop.danawa.com/main/?controller=goods&methods=index&productRegisterAreaGroupSeq=78&serviceSectionSeq=594&cate=1#1"

res=requests.get(url,headers=UA)
res.raise_for_status()

res.encoding="utf-8"

soup=BeautifulSoup(res.text, "lxml")

print(soup)
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/Article" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="DANAWA" name="apple-mobile-web-app-title"/>
# <meta content="width=1273" name="viewport"/>
# <title>CPU : 샵다나와</title>
# <meta content="CPU : 샵다나와" name="title"/>
# <meta content="컴퓨터, IT, 조립PC, 온라인견적, 역경매, 사무기기" name="keywords"/>
# <meta content="샵다나와는 코스닥 상장기업 '다나와'가 운영하는 공식쇼핑몰 입니다." name="description"/>
# <meta content="Zd_kQLEjiNKsk4p5LtRWR2AZFpJf5XlwGsmhy3iAukc" name="google-site-verification"/>
# <meta content="d70a74a8eb219a50829f8a23a44005e2b29d4c41" name="naver-site-verification"/>
# <meta content="CPU : 샵다나와" property="og:title"/>
# <meta content="샵다나와는 코스닥 상장기업 '다나와'가 운영하는 공식쇼핑몰 입니다." property="og:description"/>
# <meta content="https://img.danawa.com/new/shop_danawa/img/fb_400x400.jpg" property="og:image"/>
# <meta content="website" property="og:type"/>
# ...
